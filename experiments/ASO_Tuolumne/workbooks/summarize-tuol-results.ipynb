# %%
# !pip install statannot
# Out:
# Requirement already satisfied: statannot in /Users/tony/miniconda3/lib/python3.5/site-packages
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os
from glob import glob

import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from statannot import add_stat_annotation

import json

# %matplotlib inline

# %%
MIN_TILENO = 15

# %%
resultRoot = "/Volumes/wrangell-st-elias/research/planet/tuol-reruns/ASO_3M_SD_USCATE_20180528/"

# %%
results = glob(os.path.join(resultRoot, "*/*/*_results.json"))

# %%
len(results)
# Out:
# 12

# %%
tilenos = [int(open("/" + os.path.join(*result.split("/")[:-2] + ["tileno.txt"])).read().strip()) for result in results]

# %%
results = list(zip(results, tilenos))

# %%
results = [filepath for filepath, tileno in results if tileno > MIN_TILENO]

# %%
len(results)
# Out:
# 9

# %%
resultsData = pd.concat([pd.DataFrame(json.load(open(f))).T for f in results])

# %%
len(resultsData)
# Out:
# 27

# %%
resultsData
# Out:
#                                                     Precision    Recall  \
# 20180528_181108_1025_3B_AnalyticMS_SR_clip_merg...   0.339529  0.944016
# NDSI_largeclip.tif                                   0.310353  0.393094
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.302455  0.961819
# 20180528_181109_1025_3B_AnalyticMS_SR_clip_merg...   0.736390  0.916242
# NDSI_largeclip.tif                                   0.722061  0.549393
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.679863  0.930568
# 20180528_181110_1025_3B_AnalyticMS_SR_clip_merg...   0.780096  0.882689
# NDSI_largeclip.tif                                   0.759847  0.690366
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.716811  0.864577
# 20180528_181111_1025_3B_AnalyticMS_SR_clip_merg...   0.752746  0.848897
# NDSI_largeclip.tif                                   0.715851  0.795834
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.681332  0.824707
# 20180528_181112_1025_3B_AnalyticMS_SR_clip_merg...   0.616917  0.714767
# NDSI_largeclip.tif                                   0.560325  0.776894
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.501906  0.605542
# 20180528_181113_1025_3B_AnalyticMS_SR_clip_merg...   0.620542  0.843825
# NDSI_largeclip.tif                                   0.553694  0.683725
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.576543  0.848352
# 20180528_181320_1005_3B_AnalyticMS_SR_clip_merg...   0.657476  0.792920
# NDSI_largeclip.tif                                   0.648554  0.923231
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.625997  0.824729
# 20180528_181322_1005_3B_AnalyticMS_SR_clip_merg...   0.001856  0.007353
# NDSI_largeclip.tif                                   0.010962  0.197368
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.019756  0.029412
# 20180528_181323_1005_3B_AnalyticMS_SR_clip_merg...   0.000000  0.000000
# NDSI_largeclip.tif                                   0.000000  0.000000
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...   0.000000  0.000000
#
#                                                      F-Score  \
# 20180528_181108_1025_3B_AnalyticMS_SR_clip_merg...  0.499431
# NDSI_largeclip.tif                                  0.346857
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.460196
# 20180528_181109_1025_3B_AnalyticMS_SR_clip_merg...  0.816530
# NDSI_largeclip.tif                                  0.624003
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.785701
# 20180528_181110_1025_3B_AnalyticMS_SR_clip_merg...  0.828227
# NDSI_largeclip.tif                                  0.723442
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.783790
# 20180528_181111_1025_3B_AnalyticMS_SR_clip_merg...  0.797935
# NDSI_largeclip.tif                                  0.753727
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.746195
# 20180528_181112_1025_3B_AnalyticMS_SR_clip_merg...  0.662247
# NDSI_largeclip.tif                                  0.651072
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.548875
# 20180528_181113_1025_3B_AnalyticMS_SR_clip_merg...  0.715160
# NDSI_largeclip.tif                                  0.611877
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.686523
# 20180528_181320_1005_3B_AnalyticMS_SR_clip_merg...  0.718874
# NDSI_largeclip.tif                                  0.761892
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.711751
# 20180528_181322_1005_3B_AnalyticMS_SR_clip_merg...  0.002963
# NDSI_largeclip.tif                                  0.020771
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.023636
# 20180528_181323_1005_3B_AnalyticMS_SR_clip_merg...  0.000000
# NDSI_largeclip.tif                                  0.000000
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  0.000000
#
#                                                     Balanced Accuracy  \
# 20180528_181108_1025_3B_AnalyticMS_SR_clip_merg...           0.708446
# NDSI_largeclip.tif                                           0.571177
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.662540
# 20180528_181109_1025_3B_AnalyticMS_SR_clip_merg...           0.764991
# NDSI_largeclip.tif                                           0.650175
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.707267
# 20180528_181110_1025_3B_AnalyticMS_SR_clip_merg...           0.854039
# NDSI_largeclip.tif                                           0.768625
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.812443
# 20180528_181111_1025_3B_AnalyticMS_SR_clip_merg...           0.896816
# NDSI_largeclip.tif                                           0.866612
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.874129
# 20180528_181112_1025_3B_AnalyticMS_SR_clip_merg...           0.853191
# NDSI_largeclip.tif                                           0.882688
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.797094
# 20180528_181113_1025_3B_AnalyticMS_SR_clip_merg...           0.886948
# NDSI_largeclip.tif                                           0.804518
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.881954
# 20180528_181320_1005_3B_AnalyticMS_SR_clip_merg...           0.753584
# NDSI_largeclip.tif                                           0.788577
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.741939
# 20180528_181322_1005_3B_AnalyticMS_SR_clip_merg...           0.502863
# NDSI_largeclip.tif                                           0.595020
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.514406
# 20180528_181323_1005_3B_AnalyticMS_SR_clip_merg...           0.499887
# NDSI_largeclip.tif                                           0.500000
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...           0.499897
#
#                                                            Kappa
# 20180528_181108_1025_3B_AnalyticMS_SR_clip_merg...  2.550329e-01
# NDSI_largeclip.tif                                  1.299985e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  1.829237e-01
# 20180528_181109_1025_3B_AnalyticMS_SR_clip_merg...  5.417345e-01
# NDSI_largeclip.tif                                  2.941029e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  4.285711e-01
# 20180528_181110_1025_3B_AnalyticMS_SR_clip_merg...  6.944584e-01
# NDSI_largeclip.tif                                  5.446784e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  6.062477e-01
# 20180528_181111_1025_3B_AnalyticMS_SR_clip_merg...  7.549715e-01
# NDSI_largeclip.tif                                  7.017892e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  6.900435e-01
# 20180528_181112_1025_3B_AnalyticMS_SR_clip_merg...  6.553874e-01
# NDSI_largeclip.tif                                  6.433886e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  5.395375e-01
# 20180528_181113_1025_3B_AnalyticMS_SR_clip_merg...  6.697331e-01
# NDSI_largeclip.tif                                  5.529103e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  6.345928e-01
# 20180528_181320_1005_3B_AnalyticMS_SR_clip_merg...  4.915605e-01
# NDSI_largeclip.tif                                  5.417881e-01
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  4.613069e-01
# 20180528_181322_1005_3B_AnalyticMS_SR_clip_merg...  2.308040e-03
# NDSI_largeclip.tif                                  2.000717e-02
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0...  2.315479e-02
# 20180528_181323_1005_3B_AnalyticMS_SR_clip_merg... -8.016659e-07
# NDSI_largeclip.tif                                  0.000000e+00
# LC08_CU_003009_20180603_20190615_C01_V01_SNOW_0... -8.015230e-07

# %%
resultsData.T.reset_index()
# Out:
#                index  20180528_181108_1025_3B_AnalyticMS_SR_clip_merged.tif  \
# 0          Precision                                           0.339529
# 1             Recall                                           0.944016
# 2            F-Score                                           0.499431
# 3  Balanced Accuracy                                           0.708446
# 4              Kappa                                           0.255033
#
#    NDSI_largeclip.tif  \
# 0            0.310353
# 1            0.393094
# 2            0.346857
# 3            0.571177
# 4            0.129998
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  \
# 0                                           0.302455
# 1                                           0.961819
# 2                                           0.460196
# 3                                           0.662540
# 4                                           0.182924
#
#    20180528_181109_1025_3B_AnalyticMS_SR_clip_merged.tif  NDSI_largeclip.tif  \
# 0                                           0.736390                0.722061
# 1                                           0.916242                0.549393
# 2                                           0.816530                0.624003
# 3                                           0.764991                0.650175
# 4                                           0.541735                0.294103
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  \
# 0                                           0.679863
# 1                                           0.930568
# 2                                           0.785701
# 3                                           0.707267
# 4                                           0.428571
#
#    20180528_181110_1025_3B_AnalyticMS_SR_clip_merged.tif  NDSI_largeclip.tif  \
# 0                                           0.780096                0.759847
# 1                                           0.882689                0.690366
# 2                                           0.828227                0.723442
# 3                                           0.854039                0.768625
# 4                                           0.694458                0.544678
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  ...  \
# 0                                           0.716811             ...
# 1                                           0.864577             ...
# 2                                           0.783790             ...
# 3                                           0.812443             ...
# 4                                           0.606248             ...
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  \
# 0                                           0.576543
# 1                                           0.848352
# 2                                           0.686523
# 3                                           0.881954
# 4                                           0.634593
#
#    20180528_181320_1005_3B_AnalyticMS_SR_clip_merged.tif  NDSI_largeclip.tif  \
# 0                                           0.657476                0.648554
# 1                                           0.792920                0.923231
# 2                                           0.718874                0.761892
# 3                                           0.753584                0.788577
# 4                                           0.491560                0.541788
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  \
# 0                                           0.625997
# 1                                           0.824729
# 2                                           0.711751
# 3                                           0.741939
# 4                                           0.461307
#
#    20180528_181322_1005_3B_AnalyticMS_SR_clip_merged.tif  NDSI_largeclip.tif  \
# 0                                           0.001856                0.010962
# 1                                           0.007353                0.197368
# 2                                           0.002963                0.020771
# 3                                           0.502863                0.595020
# 4                                           0.002308                0.020007
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif  \
# 0                                           0.019756
# 1                                           0.029412
# 2                                           0.023636
# 3                                           0.514406
# 4                                           0.023155
#
#    20180528_181323_1005_3B_AnalyticMS_SR_clip_merged.tif  NDSI_largeclip.tif  \
# 0                                       0.000000e+00                     0.0
# 1                                       0.000000e+00                     0.0
# 2                                       0.000000e+00                     0.0
# 3                                       4.998869e-01                     0.5
# 4                                      -8.016659e-07                     0.0
#
#    LC08_CU_003009_20180603_20190615_C01_V01_SNOW_04_clipped.tif
# 0                                       0.000000e+00
# 1                                       0.000000e+00
# 2                                       0.000000e+00
# 3                                       4.998972e-01
# 4                                      -8.015230e-07
#
# [5 rows x 28 columns]

# %%
predictions = resultsData[resultsData.index.str.contains("merged")]
sentinel = resultsData[resultsData.index.str.contains("NDSI")]
landsat = resultsData[resultsData.index.str.contains("SNOW")]

# %%
predictions = predictions.reset_index(drop='True')
predictions['SCA'] = 'CubeSat'

# %%
sentinel = sentinel.reset_index(drop="True")
sentinel['SCA'] = "Sentinel-2"

# %%
landsat = landsat.reset_index(drop='True')
landsat['SCA'] = "Landsat 8 fSCA"

# %%
merged = pd.concat([predictions, sentinel, landsat])

# %%
# melted2 = pd.melt(merged[merged.tileno > MIN_TILENO].drop('tileno', axis=1).reset_index(), id_vars=['index', 'SCA'])
melted2 = pd.melt(merged.reset_index(), id_vars=['index', 'SCA'])
melted2 = melted2[melted2.value > 0]

# %%
box_pairs = [
    (("Precision", "CubeSat"),("Precision", "Sentinel-2")),
    (("Precision", "CubeSat"),("Precision", "Landsat 8 fSCA")),
    
    (("Recall", "CubeSat"),("Recall", "Sentinel-2")),
    (("Recall", "CubeSat"),("Recall", "Landsat 8 fSCA")),

    (("F-Score", "CubeSat"),("F-Score", "Sentinel-2")),
    (("F-Score", "CubeSat"),("F-Score", "Landsat 8 fSCA")),

    (("Balanced Accuracy", "CubeSat"),("Balanced Accuracy", "Sentinel-2")),
    (("Balanced Accuracy", "CubeSat"),("Balanced Accuracy", "Landsat 8 fSCA")),

    (("Kappa", "CubeSat"),("Kappa", "Sentinel-2")),
    (("Kappa", "CubeSat"),("Kappa", "Landsat 8 fSCA")),    
]

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
sns.set(style='ticks', font_scale=1.5)

fig, ax = plt.subplots(figsize=(11.5,5), dpi=300)
bp = sns.boxplot(x='variable', hue='SCA', y = 'value', data=melted2, ax= ax)
plt.ylim([0, 1])
plt.xlabel("")
plt.ylabel("")
# ax.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
plt.tight_layout()
plt.savefig("tuol-sentinel-ml-performance.png", dpi=300, bbox_inches='tight')
test_results = add_stat_annotation(ax, data=melted2, x='variable', y='value', hue='SCA',
                                   box_pairs=box_pairs,
                                   test='t-test_ind', text_format='star',
                                   loc='outside', verbose=2)
plt.savefig("tuol-sentinel-ml-performance_sig.png", dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# F-Score_CubeSat v.s. F-Score_Sentinel-2: t-test independent samples, P_val=6.137e-01 stat=5.162e-01
# Balanced Accuracy_CubeSat v.s. Balanced Accuracy_Sentinel-2: t-test independent samples, P_val=6.418e-01 stat=4.742e-01
# Kappa_CubeSat v.s. Kappa_Sentinel-2: t-test independent samples, P_val=5.407e-01 stat=6.271e-01
# Precision_CubeSat v.s. Precision_Sentinel-2: t-test independent samples, P_val=8.330e-01 stat=2.148e-01
# Recall_CubeSat v.s. Recall_Sentinel-2: t-test independent samples, P_val=4.043e-01 stat=8.600e-01
# F-Score_CubeSat v.s. F-Score_Landsat 8 fSCA: t-test independent samples, P_val=7.860e-01 stat=2.767e-01
# Balanced Accuracy_CubeSat v.s. Balanced Accuracy_Landsat 8 fSCA: t-test independent samples, P_val=7.184e-01 stat=3.670e-01
# Kappa_CubeSat v.s. Kappa_Landsat 8 fSCA: t-test independent samples, P_val=6.192e-01 stat=5.082e-01
# Recall_CubeSat v.s. Recall_Landsat 8 fSCA: t-test independent samples, P_val=9.609e-01 stat=4.994e-02
# Precision_CubeSat v.s. Precision_Landsat 8 fSCA: t-test independent samples, P_val=6.979e-01 stat=3.963e-01
