# %%
import rasterio as rio
from rasterio.mask import mask
import pandas as pd
import geopandas as gpd
import cartopy.crs as ccrs
from os import path, remove
import pyproj
import numpy as np
from xml.dom import minidom
from shapely.geometry import Point, mapping

from glob import glob
import re
from subprocess import call

# %% [markdown]
# # Image Data Extraction Pipeline
# The purpose here is to get all of the images in a directory, extract an area of interest from them, get pixel values, and add a row to a database for each pixel in the area of interest within each image.

# %%
IMAGEDIR = "../images/2016/snow"
locfile = "these_locations.csv"
outfilename = "PROVISIONAL_2016_snow_datatable.csv"
TOA_ADJUST = False
file_search_format = "*_*.zip"
filename_regex = "(\d*)_(.*).zip"

# %%
files = list(glob(path.join(IMAGEDIR, file_search_format)))
locations = pd.read_csv(path.join(IMAGEDIR, locfile)).set_index("id")

# %%
def process_file(fullpath):
    
    filename = path.basename(fullpath)
    match = re.search(filename_regex, filename)
    loc_id = match[1]
    img_id = match[2]
    print("Unzipping..."+fullpath)
    call(['unzip', fullpath])

    loc = locations.loc[int(loc_id)]
    # Read File
    print(glob("*AnalyticMS_clip.tif")[0])
    raster = rio.open(glob("*AnalyticMS_clip.tif")[0])

    # Get TOA Coefficeints from metadata
    meta = minidom.parse(glob("*AnalyticMS_metadata_clip.xml")[0])
    nodes = meta.getElementsByTagName("ps:bandSpecificMetadata")

    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
            
    rast_proj = pyproj.Proj(init=raster.crs['init'])
    buf_proj = pyproj.Proj(init='epsg:4326')
    
    lon, lat = pyproj.transform(buf_proj, rast_proj, loc.longitude, loc.latitude)
    buf = mapping(Point(lon, lat).buffer(5))
    
    print("{lo} {la} --> {ulo} {ula}".format(lo=loc.longitude, la=loc.latitude,
                                             ulo=lon, ula=lat))
    print(raster.bounds)
    
    try: 
        out_image, out_transform = mask(raster, [buf], crop=True)
    except Exception as e:
        print(e) 
        for f in glob(img_id+"*"):
            print("Deleting " + f)
            remove(f)
        raise Exception

    no_data = raster.nodata
    data = out_image.data[0]
    
    reflectance = np.extract(data != no_data, data)
    row, col = np.where(data != no_data) 
    T1 = out_transform * rio.Affine.translation(0.5, 0.5) # reference the pixel centre
    rc2xy = lambda r, c: (c, r) * T1 
    
    d = gpd.GeoDataFrame({'col':col,'row':row, 'loc':loc_id, 'img': img_id})
    # coordinate transformation
    try:
        d['x_geotiff'] = d.apply(lambda row: rc2xy(row.row,row.col)[0], axis=1)
        d['y_geotiff'] = d.apply(lambda row: rc2xy(row.row,row.col)[1], axis=1)
        d['geometry'] =d.apply(lambda row: Point(row['x_geotiff'], row['y_geotiff']), axis=1)
        for band in range(4):
            # read + TOA normalize
            data = out_image.data[band]    
            if(TOA_ADJUST):
                reflectance = np.extract(data != no_data, data) * coeffs[band + 1] 
            else:
                reflectance = np.extract(data != no_data, data)
            d['band'+str(band+1)] = pd.Series(reflectance, index=d.index)
    except Exception as e:
        for f in glob(img_id+"*"):
            print("Deleting " + f)
            remove(f)
        print(e)
        print("Error reading, aborted.")
        raise Exception("Error reading")

        
    d.crs = raster.crs
    d = d.to_crs({'init':'epsg:4326'})
    
        
    
    for f in glob(img_id+"*"):
        print("Deleting " + f)
        remove(f)
    
    print('done')
    return(d.drop(['row', 'col'], axis=1))

# %%
dfs = []
for file in files:
    print(file)
    try:
        ans = process_file(file)
    except Exception as e:
        print(e)
        print("Error, skipping")
        continue
    dfs.append(ans)
    
dfs = pd.concat(dfs)
# Out:
# ../images/2016/snow/1882_20170119_181700_0e20.zip
# Unzipping...../images/2016/snow/1882_20170119_181700_0e20.zip
# 20170119_181700_0e20_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20170119_181700_0e20_3B_AnalyticMS_DN_udm_clip.tif
# Deleting 20170119_181700_0e20_3B_AnalyticMS_clip.tif
# Deleting 20170119_181700_0e20_3B_AnalyticMS_metadata_clip.xml
# done
# ../images/2016/snow/1882_20170105_174048_0c45.zip
# Unzipping...../images/2016/snow/1882_20170105_174048_0c45.zip
# 20170105_174048_0c45_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20170105_174048_0c45_3B_AnalyticMS_metadata_clip.xml
# Deleting 20170105_174048_0c45_3B_AnalyticMS_clip.tif
# Deleting 20170105_174048_0c45_3B_AnalyticMS_DN_udm_clip.tif
# done
# ../images/2016/snow/1882_20161206_181601_0e19.zip
# Unzipping...../images/2016/snow/1882_20161206_181601_0e19.zip
# 20161206_181601_0e19_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20161206_181601_0e19_3B_AnalyticMS_metadata_clip.xml
# Deleting 20161206_181601_0e19_3B_AnalyticMS_DN_udm_clip.tif
# Deleting 20161206_181601_0e19_3B_AnalyticMS_clip.tif
# done
# ../images/2016/snow/1882_20161231_181637_0e19.zip
# Unzipping...../images/2016/snow/1882_20161231_181637_0e19.zip
# 20161231_181637_0e19_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20161231_181637_0e19_3B_AnalyticMS_clip.tif
# Deleting 20161231_181637_0e19_3B_AnalyticMS_metadata_clip.xml
# Deleting 20161231_181637_0e19_3B_AnalyticMS_DN_udm_clip.tif
# Cannot set a frame with no defined index and a value that cannot be converted to a Series
# Error reading, aborted.
# Error reading
# Error, skipping
# ../images/2016/snow/353_20160302_160252_0c73.zip
# Unzipping...../images/2016/snow/353_20160302_160252_0c73.zip
# 20160302_160252_0c73_3B_AnalyticMS_clip.tif
# -121.8483189 46.96105451 --> 587620.425761753 5201479.9269890385
# BoundingBox(left=587232.0, bottom=5201130.0, right=588006.0, top=5202042.0)
# Deleting 20160302_160252_0c73_3B_AnalyticMS_clip.tif
# Deleting 20160302_160252_0c73_3B_AnalyticMS_metadata_clip.xml
# Deleting 20160302_160252_0c73_3B_AnalyticMS_DN_udm_clip.tif
# Cannot set a frame with no defined index and a value that cannot be converted to a Series
# Error reading, aborted.
# Error reading
# Error, skipping
# ../images/2016/snow/1882_20161231_181636_0e19.zip
# Unzipping...../images/2016/snow/1882_20161231_181636_0e19.zip
# 20161231_181636_0e19_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20161231_181636_0e19_3B_AnalyticMS_metadata_clip.xml
# Deleting 20161231_181636_0e19_3B_AnalyticMS_clip.tif
# Deleting 20161231_181636_0e19_3B_AnalyticMS_DN_udm_clip.tif
# done
# ../images/2016/snow/1882_20161207_181505_0e0e.zip
# Unzipping...../images/2016/snow/1882_20161207_181505_0e0e.zip
# 20161207_181505_0e0e_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20161207_181505_0e0e_3B_AnalyticMS_metadata_clip.xml
# Deleting 20161207_181505_0e0e_3B_AnalyticMS_clip.tif
# Deleting 20161207_181505_0e0e_3B_AnalyticMS_DN_udm_clip.tif
# done
# ../images/2016/snow/843_20160716_144201_0c19.zip
# Unzipping...../images/2016/snow/843_20160716_144201_0c19.zip
# 20160716_144201_0c19_3B_AnalyticMS_clip.tif
# -121.71035 46.7975 --> 598415.6975781143 5183468.859612337
# BoundingBox(left=598026.0, bottom=5182908.0, right=598806.0, top=5184030.0)
# Deleting 20160716_144201_0c19_3B_AnalyticMS_DN_udm_clip.tif
# Deleting 20160716_144201_0c19_3B_AnalyticMS_clip.tif
# Deleting 20160716_144201_0c19_3B_AnalyticMS_metadata_clip.xml
# done
# ../images/2016/snow/843_20160706_141857_1_0c2b.zip
# Unzipping...../images/2016/snow/843_20160706_141857_1_0c2b.zip
# 20160706_141857_1_0c2b_3B_AnalyticMS_clip.tif
# -121.71035 46.7975 --> 598415.6975781143 5183468.859612337
# BoundingBox(left=598026.0, bottom=5182908.0, right=598806.0, top=5184030.0)
# Deleting 20160706_141857_1_0c2b_3B_AnalyticMS_metadata_clip.xml
# Deleting 20160706_141857_1_0c2b_3B_AnalyticMS_clip.tif
# Deleting 20160706_141857_1_0c2b_3B_AnalyticMS_DN_udm_clip.tif
# done
# ../images/2016/snow/1882_20170105_174047_1_0c45.zip
# Unzipping...../images/2016/snow/1882_20170105_174047_1_0c45.zip
# 20170105_174047_1_0c45_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20170105_174047_1_0c45_3B_AnalyticMS_DN_udm_clip.tif
# Deleting 20170105_174047_1_0c45_3B_AnalyticMS_metadata_clip.xml
# Deleting 20170105_174047_1_0c45_3B_AnalyticMS_clip.tif
# Cannot set a frame with no defined index and a value that cannot be converted to a Series
# Error reading, aborted.
# Error reading
# Error, skipping
# ../images/2016/snow/1882_20170112_181733_0e16.zip
# Unzipping...../images/2016/snow/1882_20170112_181733_0e16.zip
# 20170112_181733_0e16_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20170112_181733_0e16_3B_AnalyticMS_clip.tif
# Deleting 20170112_181733_0e16_3B_AnalyticMS_metadata_clip.xml
# Deleting 20170112_181733_0e16_3B_AnalyticMS_DN_udm_clip.tif
# Cannot set a frame with no defined index and a value that cannot be converted to a Series
# Error reading, aborted.
# Error reading
# Error, skipping
# ../images/2016/snow/1882_20170112_181732_0e16.zip
# Unzipping...../images/2016/snow/1882_20170112_181732_0e16.zip
# 20170112_181732_0e16_3B_AnalyticMS_clip.tif
# -121.8872 46.99467 --> 584609.311164629 5205172.702328316
# BoundingBox(left=584220.0, bottom=5204613.0, right=584997.0, top=5205735.0)
# Deleting 20170112_181732_0e16_3B_AnalyticMS_clip.tif
# Deleting 20170112_181732_0e16_3B_AnalyticMS_DN_udm_clip.tif
# Deleting 20170112_181732_0e16_3B_AnalyticMS_metadata_clip.xml
# done

# %%
dfs.to_csv(path.join(IMAGEDIR, outfilename))

# %%
len(dfs)
# Out:
# 76

# %%
dfs
# Out:
#                        img   loc  x_geotiff  y_geotiff  \
# 0     20170119_181700_0e20  1882   584605.5  5205175.5
# 1     20170119_181700_0e20  1882   584608.5  5205175.5
# 2     20170119_181700_0e20  1882   584611.5  5205175.5
# 3     20170119_181700_0e20  1882   584605.5  5205172.5
# 4     20170119_181700_0e20  1882   584608.5  5205172.5
# 5     20170119_181700_0e20  1882   584611.5  5205172.5
# 6     20170119_181700_0e20  1882   584605.5  5205169.5
# 7     20170119_181700_0e20  1882   584608.5  5205169.5
# 8     20170119_181700_0e20  1882   584611.5  5205169.5
# 0     20170105_174048_0c45  1882   584605.5  5205175.5
# 1     20170105_174048_0c45  1882   584608.5  5205175.5
# 2     20170105_174048_0c45  1882   584611.5  5205175.5
# 3     20170105_174048_0c45  1882   584605.5  5205172.5
# 4     20170105_174048_0c45  1882   584608.5  5205172.5
# 5     20170105_174048_0c45  1882   584611.5  5205172.5
# 6     20170105_174048_0c45  1882   584605.5  5205169.5
# 7     20170105_174048_0c45  1882   584608.5  5205169.5
# 8     20170105_174048_0c45  1882   584611.5  5205169.5
# 0     20161206_181601_0e19  1882   584605.5  5205175.5
# 1     20161206_181601_0e19  1882   584608.5  5205175.5
# 2     20161206_181601_0e19  1882   584611.5  5205175.5
# 3     20161206_181601_0e19  1882   584605.5  5205172.5
# 4     20161206_181601_0e19  1882   584608.5  5205172.5
# 5     20161206_181601_0e19  1882   584611.5  5205172.5
# 6     20161206_181601_0e19  1882   584605.5  5205169.5
# 7     20161206_181601_0e19  1882   584608.5  5205169.5
# 8     20161206_181601_0e19  1882   584611.5  5205169.5
# 0     20161231_181636_0e19  1882   584605.5  5205175.5
# 1     20161231_181636_0e19  1882   584608.5  5205175.5
# 2     20161231_181636_0e19  1882   584611.5  5205175.5
# ..                     ...   ...        ...        ...
